# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
london_crime = pd.read_csv("london_crime_by_lsoa.csv")

# %%
london_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
london_crime.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
print(london_crime["borough"].unique())
print(london_crime["major_category"].unique())
# Out:
# ['Croydon' 'Greenwich' 'Bromley' 'Redbridge' 'Wandsworth' 'Ealing'
#  'Hounslow' 'Newham' 'Sutton' 'Haringey' 'Lambeth' 'Richmond upon Thames'
#  'Hillingdon' 'Havering' 'Barking and Dagenham' 'Kingston upon Thames'
#  'Westminster' 'Hackney' 'Enfield' 'Harrow' 'Lewisham' 'Brent' 'Southwark'
#  'Barnet' 'Waltham Forest' 'Camden' 'Bexley' 'Kensington and Chelsea'
#  'Islington' 'Tower Hamlets' 'Hammersmith and Fulham' 'Merton'
#  'City of London']
# ['Burglary' 'Violence Against the Person' 'Robbery' 'Theft and Handling'
#  'Criminal Damage' 'Drugs' 'Fraud or Forgery' 'Other Notifiable Offences'
#  'Sexual Offences']

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# ## Line Plot (Single)
#
# **----------------------------1. Total crime over 2008-2016----------------------------**

# %%
total_crime = london_crime.drop(["lsoa_code","borough","major_category","minor_category","month"], axis=1)

# %%
total_crime = total_crime.groupby("year").sum()
total_crime
# Out:
#        value
# year
# 2008  738641
# 2009  717214
# 2010  715324
# 2011  724915
# 2012  737329
# 2013  686407
# 2014  680183
# 2015  711624
# 2016  736121

# %%
total_crime.plot(figsize=(10,5), legend=False, linewidth=5, color="r")
plt.title("Number of Crime in London between 2008 to 2016\n", fontsize=20)
plt.xlabel("\nYears", fontsize=15)
plt.ylabel("Number of Crime\n", fontsize=15)
plt.grid(color="grey", linewidth=1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# **----------------------------2. Total crime di salah satu borough over the year----------------------------**

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
borough_crime = london_crime.drop(["major_category","minor_category","month","lsoa_code"],axis=1)
borough_crime
# Out:
#              borough  value  year
# 0            Croydon      0  2016
# 1          Greenwich      0  2016
# 2            Bromley      0  2015
# 3          Redbridge      0  2016
# 4         Wandsworth      0  2008
# ...              ...    ...   ...
# 13490599       Brent      0  2015
# 13490600  Hillingdon      1  2015
# 13490601      Sutton      0  2011
# 13490602     Croydon      0  2011
# 13490603      Merton      0  2015
#
# [13490604 rows x 3 columns]

# %%
croydon_crime = borough_crime.set_index("borough")
croydon_crime = croydon_crime.loc["Croydon"].groupby("year").sum()
croydon_crime
# Out:
#       value
# year
# 2008  29516
# 2009  29784
# 2010  29373
# 2011  29830
# 2012  30189
# 2013  27444
# 2014  27357
# 2015  28089
# 2016  28712

# %%
croydon_crime.plot(figsize=(10,5), legend=False, linewidth=5, color="b")
plt.title("Number of Crime in Croydon between 2008 to 2016\n", fontsize=20)
plt.xlabel("\nYears", fontsize=15)
plt.ylabel("Number of Crime\n", fontsize=15)
plt.grid(color="grey", linewidth=1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
london_crime["borough"].unique()
# Out:
# array(['Croydon', 'Greenwich', 'Bromley', 'Redbridge', 'Wandsworth',
#        'Ealing', 'Hounslow', 'Newham', 'Sutton', 'Haringey', 'Lambeth',
#        'Richmond upon Thames', 'Hillingdon', 'Havering',
#        'Barking and Dagenham', 'Kingston upon Thames', 'Westminster',
#        'Hackney', 'Enfield', 'Harrow', 'Lewisham', 'Brent', 'Southwark',
#        'Barnet', 'Waltham Forest', 'Camden', 'Bexley',
#        'Kensington and Chelsea', 'Islington', 'Tower Hamlets',
#        'Hammersmith and Fulham', 'Merton', 'City of London'], dtype=object)

# %%
while True:
    insert_borough = input("")
    if not insert_borough in london_crime["borough"].unique(): 
        print("ERROR! Please insert the right borough")
        break;
    if insert_borough in london_crime["borough"].unique():
        borough_crime = london_crime.drop(["major_category","minor_category","month","lsoa_code"],axis=1)
        borough_crime = borough_crime.set_index("borough")
        borough_crime = borough_crime.loc[insert_borough].groupby("year").sum()
        borough_crime.plot(figsize=(10,5), legend=False, linewidth=5, color="b")
        plt.title("Number of Crime in {} between 2008 to 2016\n".format(insert_borough), fontsize=20)
        plt.xlabel("\nYears", fontsize=15)
        plt.ylabel("Number of Crime\n", fontsize=15)
        plt.grid(color="grey", linewidth=0.5)
        plt.xticks(fontsize=10)
        plt.yticks(fontsize=10)
        plt.show()
print()
# Out:
# Greenwich
# Harrow
# City of London
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-baff56d86bcb> in <module>
#       1 while True:
# ----> 2     insert_borough = input("")
#       3     if not insert_borough in london_crime["borough"].unique():
#       4         print("ERROR! Please insert the right borough")
#       5         break;
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %% [markdown]
# **----------------------------3. Total salah satu major crime over the year----------------------------**

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
print(london_crime["major_category"].unique())
# Out:
# ['Burglary' 'Violence Against the Person' 'Robbery' 'Theft and Handling'
#  'Criminal Damage' 'Drugs' 'Fraud or Forgery' 'Other Notifiable Offences'
#  'Sexual Offences']

# %%
major_crime = london_crime.drop(["borough","minor_category","month","lsoa_code"],axis=1)
major_crime = major_crime.set_index("major_category")
major_crime
# Out:
#                              value  year
# major_category
# Burglary                         0  2016
# Violence Against the Person      0  2016
# Violence Against the Person      0  2015
# Burglary                         0  2016
# Robbery                          0  2008
# ...                            ...   ...
# Criminal Damage                  0  2015
# Robbery                          1  2015
# Burglary                         0  2011
# Robbery                          0  2011
# Violence Against the Person      0  2015
#
# [13490604 rows x 2 columns]

# %%
robbery_crime = major_crime.loc["Robbery"].groupby("year").sum()
robbery_crime
# Out:
#       value
# year
# 2008  29627
# 2009  29568
# 2010  32341
# 2011  36679
# 2012  35260
# 2013  29337
# 2014  22150
# 2015  21383
# 2016  22528

# %%
robbery_crime.plot(figsize=(20,10), legend=False, linewidth=5, color="g")
plt.title("Number of Robbery Crime in London between 2008 to 2016\n", fontsize=30)
plt.xlabel("\nYears", fontsize=25)
plt.ylabel("Number of Crime\n", fontsize=25)
plt.grid(color="grey", linewidth=1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
while True:
    insert_crime_category = input("")
    if not insert_crime_category in london_crime["major_category"].unique(): break;
    if insert_crime_category in london_crime["major_category"].unique():
        major_crime = london_crime.drop(["borough","minor_category","month","lsoa_code"],axis=1)
        major_crime = major_crime.set_index("major_category")
        major_crime = major_crime.loc[insert_crime_category].groupby("year").sum()
        major_crime.plot(figsize=(10,5), legend=False, linewidth=5, color="g")
        plt.title("Number of {} Crime in London between 2008 to 2016\n".format(insert_crime_category), fontsize=20)
        plt.xlabel("\nYears", fontsize=15)
        plt.ylabel("Number of Crime\n", fontsize=15)
        plt.grid(color="grey", linewidth=0.5)
        plt.xticks(fontsize=10)
        plt.yticks(fontsize=10)
        plt.show()
print()
# Out:
# Theft and Handling
# Drugs
# Sexual Offences
# STOP

# %% [markdown]
# **------Total Crime based on Minor Category over 2008-2016-----**

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
minor_crime = london_crime.drop(["lsoa_code","borough","major_category","month"], axis=1)
minor_crime = minor_crime.set_index("minor_category")
minor_crime
# Out:
#                              value  year
# minor_category
# Burglary in Other Buildings      0  2016
# Other violence                   0  2016
# Other violence                   0  2015
# Burglary in Other Buildings      0  2016
# Personal Property                0  2008
# ...                            ...   ...
# Criminal Damage To Dwelling      0  2015
# Personal Property                1  2015
# Burglary in a Dwelling           0  2011
# Business Property                0  2011
# Wounding/GBH                     0  2015
#
# [13490604 rows x 2 columns]

# %%
london_crime["minor_category"].unique()
# Out:
# array(['Burglary in Other Buildings', 'Other violence',
#        'Personal Property', 'Other Theft', 'Offensive Weapon',
#        'Criminal Damage To Other Building', 'Theft/Taking of Pedal Cycle',
#        'Motor Vehicle Interference & Tampering',
#        'Theft/Taking Of Motor Vehicle', 'Wounding/GBH',
#        'Other Theft Person', 'Common Assault', 'Theft From Shops',
#        'Possession Of Drugs', 'Harassment', 'Handling Stolen Goods',
#        'Criminal Damage To Dwelling', 'Burglary in a Dwelling',
#        'Criminal Damage To Motor Vehicle', 'Other Criminal Damage',
#        'Counted per Victim', 'Going Equipped', 'Other Fraud & Forgery',
#        'Assault with Injury', 'Drug Trafficking', 'Other Drugs',
#        'Business Property', 'Other Notifiable', 'Other Sexual',
#        'Theft From Motor Vehicle', 'Rape', 'Murder'], dtype=object)

# %%
theft_crime = minor_crime.loc["Theft From Shops"].groupby("year").sum()
theft_crime
# Out:
#       value
# year
# 2008  32857
# 2009  36349
# 2010  36935
# 2011  36351
# 2012  36562
# 2013  36441
# 2014  40141
# 2015  42549
# 2016  46957

# %%
theft_crime.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## Area Plot / Multiple Line Plot

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
top5_crime = london_crime.drop(["lsoa_code","major_category","minor_category","month"], axis=1)
top5_crime = top5_crime.set_index("year").groupby("borough").sum()
top5_crime = top5_crime.sort_values(by="value", ascending=False).head(5)
top5_crime
# Out:
#               value
# borough
# Westminster  455028
# Lambeth      292178
# Southwark    278809
# Camden       275147
# Newham       262024

# %%
df_top5 = london_crime.drop(["lsoa_code","major_category","minor_category","month"], axis=1).set_index("borough")
df_top5 = df_top5.loc[top5_crime.index]
df_top5 = pd.pivot_table(df_top5, values="value", aggfunc=np.sum, index="year", columns="borough")
df_top5
# Out:
# borough  Camden  Lambeth  Newham  Southwark  Westminster
# year
# 2008      32010    31717   29752      33470        47846
# 2009      31612    31225   28610      30623        48456
# 2010      31804    31671   30728      31320        48116
# 2011      33956    33224   27978      30723        54243
# 2012      31472    33473   30067      30737        59226
# 2013      28435    31868   27577      31128        53852
# 2014      27198    31765   28005      28912        47564
# 2015      29477    33164   29217      30260        47395
# 2016      29183    34071   30090      31636        48330

# %%
df_top5.plot(kind="area",
             figsize=(10,5),
             stacked=True,
             alpha = 0.4)
plt.title("Top 5 Borough with the Highest Crime Number [2008-2016]\n", fontsize=25)
plt.xlabel("\nYear", fontsize=20)
plt.ylabel("Number of Crime\n", fontsize=20)
plt.grid(color="grey", linewidth=0.5)
plt.show()

# %%
df_top5.plot(kind="line", figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_top5.plot(kind="area",
             figsize=(20,10),
             stacked=False,
             alpha = 0.4)
plt.title("Top 5 Borough with the Highest Crime Number [2008-2016]\n", fontsize=25)
plt.xlabel("\nYear", fontsize=20)
plt.ylabel("Number of Crime\n", fontsize=20)
plt.grid(color="grey", linewidth=0.5)
plt.show()

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
top5_major = london_crime.drop(["lsoa_code","borough","minor_category","month"], axis=1)
top5_major.set_index("year", inplace=True)
top5_major = top5_major.groupby("major_category").sum()
top5_major = top5_major.sort_values(by="value", ascending=False).head(5)
top5_major
# Out:
#                                value
# major_category
# Theft and Handling           2661861
# Violence Against the Person  1558081
# Burglary                      754293
# Criminal Damage               630938
# Drugs                         470765

# %%
df_top5major = london_crime.drop(["lsoa_code","borough","minor_category","month"], axis=1).set_index("major_category")
df_top5major = df_top5major.loc[top5_major.index]
df_top5major = pd.pivot_table(df_top5major, values="value", aggfunc=np.sum, index="year", columns="major_category")
df_top5major
# Out:
# major_category  Burglary  Criminal Damage  Drugs  Theft and Handling  \
# year
# 2008               88092            91872  68804              283692
# 2009               90619            85565  60549              279492
# 2010               86826            77897  58674              290924
# 2011               93315            70914  57550              309292
# 2012               93392            62158  51776              334054
# 2013               87222            56206  50278              306372
# 2014               76053            59279  44435              279880
# 2015               70489            62976  39785              284022
# 2016               68285            64071  38914              294133
#
# major_category  Violence Against the Person
# year
# 2008                                 159844
# 2009                                 160777
# 2010                                 157894
# 2011                                 146901
# ...

# %%
df_top5major.plot(kind="line", figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_top5major.plot(kind="area", figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
top5_minor = london_crime.drop(["lsoa_code","borough","major_category","month"], axis=1).set_index("year")
top5_minor = top5_minor.groupby("minor_category").sum()
top5_minor = top5_minor.sort_values(by="value", ascending=False).head(5)
top5_minor
# Out:
#                            value
# minor_category
# Other Theft               980085
# Theft From Motor Vehicle  569956
# Burglary in a Dwelling    491282
# Harassment                458124
# Assault with Injury       451001

# %%
df_top5minor = london_crime.drop(["lsoa_code","borough","major_category","month"], axis=1).set_index("minor_category")
df_top5minor = df_top5minor.loc[top5_minor.index]
df_top5minor = pd.pivot_table(df_top5minor, values="value", aggfunc=np.sum, index="year", columns="minor_category")
df_top5minor
# Out:
# minor_category  Assault with Injury  Burglary in a Dwelling  Harassment  \
# year
# 2008                          56586                   56655       43389
# 2009                          55297                   60185       43594
# 2010                          54173                   57123       42808
# 2011                          50768                   62439       37493
# 2012                          50369                   61716       43396
# 2013                          39929                   56537       41805
# 2014                          45677                   48975       55330
# 2015                          48164                   44656       71633
# 2016                          50038                   42996       78676
#
# minor_category  Other Theft  Theft From Motor Vehicle
# year
# 2008                  99280                     76570
# 2009                  95424                     68856
# 2010                 103997                     69709
# ...

# %%
df_top5minor.plot(kind="line", figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df_top5minor.plot(kind="area", figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
london_crime["month"].unique()
# Out:
# array([11,  5,  3,  6,  7,  4,  9,  8, 12,  1, 10,  2], dtype=int64)

# %%
london_crime.set_index("month", inplace=True)
london_crime
# Out:
#        lsoa_code     borough               major_category  \
# month
# 11     E01001116     Croydon                     Burglary
# 11     E01001646   Greenwich  Violence Against the Person
# 5      E01000677     Bromley  Violence Against the Person
# 3      E01003774   Redbridge                     Burglary
# 6      E01004563  Wandsworth                      Robbery
# ...          ...         ...                          ...
# 2      E01000504       Brent              Criminal Damage
# 6      E01002504  Hillingdon                      Robbery
# 2      E01004165      Sutton                     Burglary
# 5      E01001134     Croydon                      Robbery
# 6      E01003413      Merton  Violence Against the Person
#
#                     minor_category  value  year
# month
# 11     Burglary in Other Buildings      0  2016
# 11                  Other violence      0  2016
# 5                   Other violence      0  2015
# 3      Burglary in Other Buildings      0  2016
# ...

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month = np.arange(1, 13)
month_map = {i+1:month for i, month in enumerate(months)}
london_crime.rename(index=month_map, level=0, inplace=True)

# %%
london_crime.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-2576c1e14a79> in <module>
#       1 london_crime.reset_index(inplace=True)
# ----> 2 london_crime.drop("index", axis=1, inplace=True)
#       3 london_crime
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4154
#    4155         if inplace:
# -> 4156             self._update_inplace(obj)
#    4157         else:
#    4158             return obj
#
# ...

# %%
london_crime.drop("index", axis=1, inplace=True)
london_crime
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-3ed87c48cfe1> in <module>
# ----> 1 london_crime.drop("index", axis=1, inplace=True)
#       2 london_crime
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
london_crime.drop("level_0", axis=1, inplace=True)
london_crime
# Out:
#          month  lsoa_code     borough               major_category  \
# 0          Nov  E01001116     Croydon                     Burglary
# 1          Nov  E01001646   Greenwich  Violence Against the Person
# 2          May  E01000677     Bromley  Violence Against the Person
# 3          Mar  E01003774   Redbridge                     Burglary
# 4          Jun  E01004563  Wandsworth                      Robbery
# ...        ...        ...         ...                          ...
# 13490599   Feb  E01000504       Brent              Criminal Damage
# 13490600   Jun  E01002504  Hillingdon                      Robbery
# 13490601   Feb  E01004165      Sutton                     Burglary
# 13490602   May  E01001134     Croydon                      Robbery
# 13490603   Jun  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year
# 0         Burglary in Other Buildings      0  2016
# 1                      Other violence      0  2016
# ...

# %%
month_crime = london_crime.drop(["lsoa_code","borough","major_category","minor_category"], axis=1)
month_crime = pd.pivot_table(month_crime, index="month", values="value", columns="year", aggfunc=np.sum)
month_crime
# Out:
# year    2008   2009   2010   2011   2012   2013   2014   2015   2016
# month
# Apr    59640  59181  60085  58714  58801  55678  53467  56445  58637
# Aug    59959  58695  59040  59117  62143  57467  55641  58056  62666
# Dec    57488  54235  51536  59680  58618  54209  57565  60840  62455
# Feb    62626  54706  55069  54895  56735  55271  51222  53316  56697
# Jan    65419  59142  54934  57966  62436  58933  55515  57055  58847
# Jul    64126  63281  63764  62428  63280  60508  58564  61606  65519
# Jun    62290  63116  62632  61822  62281  56839  57039  60760  62262
# Mar    61343  63482  63629  61282  67537  57590  57669  60096  59167
# May    62587  62897  62126  62630  64344  56765  56327  61038  63990
# Nov    61395  59456  60665  64119  62514  58267  59704  62487  61064
# Oct    63354  61176  62113  63622  61728  59956  60537  62361  63405
# Sep    58414  57847  59731  58640  56912  54924  56933  57564  61412

# %%
month_crime.plot(kind="line", figsize=(20,10), linewidth=3)
# Out:
# <AxesSubplot:xlabel='month'>

# %%
total_month = london_crime.drop(["lsoa_code","borough","major_category","minor_category", "year"], axis=1)
total_month = total_month.groupby("month").sum()
total_month
# Out:
#         value
# month
# Apr    520648
# Aug    532784
# Dec    516626
# Feb    500537
# Jan    530247
# Jul    563076
# Jun    549041
# Mar    551795
# May    552704
# Nov    549671
# Oct    558252
# Sep    522377

# %%
total_month.plot(figsize=(20,10), linewidth=5)
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# ## Histogram

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
crime_frequency = london_crime.drop(["lsoa_code","major_category","minor_category","month","year"], axis=1)
crime_frequency = crime_frequency.groupby("borough").sum()
crime_frequency
# Out:
#                          value
# borough
# Barking and Dagenham    149447
# Barnet                  212191
# Bexley                  114136
# Brent                   227551
# Bromley                 184349
# Camden                  275147
# City of London             780
# Croydon                 260294
# Ealing                  251562
# Enfield                 193880
# Greenwich               181568
# Hackney                 217119
# Hammersmith and Fulham  185259
# Haringey                213272
# Harrow                  116848
# Havering                138947
# Hillingdon              209680
# Hounslow                186772
# Islington               230286
# Kensington and Chelsea  171981
# Kingston upon Thames     89306
# Lambeth                 292178
# Lewisham                215137
# Merton                  115654
# Newham                  262024
# Redbridge               183562
# Richmond upon Thames     96771
# Southwark               278809
# Sutton                  100987
# ...

# %%
count, bin_edges = np.histogram(crime_frequency)
print(count)
print(bin_edges)
# Out:
# [ 1  1  5  4 13  5  3  0  0  1]
# [   780.   46204.8  91629.6 137054.4 182479.2 227904.  273328.8 318753.6
#  364178.4 409603.2 455028. ]

# %%
crime_frequency.plot(kind="hist",
                     figsize=(10,7),
                     xticks=bin_edges,
                     yticks=count,
                     legend=False,
                     color="indianred")
plt.title("Crime Frequency from 33 Borough in London [2008-2016]\n", fontsize=20)
plt.xlabel("\nNumber of Crime", fontsize=15)
plt.ylabel("Number of Borough\n", fontsize=15)
plt.grid(color="grey", linewidth=0.5)
plt.show()

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
year_frequency = london_crime.drop(["lsoa_code","borough","major_category","minor_category","month"], axis=1)
year_frequency = year_frequency.groupby("year").sum()
year_frequency
# Out:
#        value
# year
# 2008  738641
# 2009  717214
# 2010  715324
# 2011  724915
# 2012  737329
# 2013  686407
# 2014  680183
# 2015  711624
# 2016  736121

# %%
count, bin_edges = np.histogram(year_frequency)
print(count)
print(bin_edges)
# Out:
# [1 1 0 0 0 1 2 1 0 3]
# [680183.  686028.8 691874.6 697720.4 703566.2 709412.  715257.8 721103.6
#  726949.4 732795.2 738641. ]

# %%
year_frequency.plot(kind="hist",
                     figsize=(10,7),
                     xticks=bin_edges,
                     yticks=count,
                     legend=False,
                     color="blue")
#plt.title("Histogram of , fontsize=20)
plt.xlabel("\nNumber of Crime", fontsize=15)
plt.ylabel("Number of Year\n", fontsize=15)
plt.grid(color="grey", linewidth=0.5)
plt.show()

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
frequency16 = london_crime.drop(["lsoa_code","major_category","minor_category","month"], axis=1).set_index("year")
frequency16 = frequency16.loc[2016]
frequency16 = frequency16.groupby("borough").sum()
frequency16
# Out:
#                         value
# borough
# Barking and Dagenham    16741
# Barnet                  24684
# Bexley                  12840
# Brent                   26693
# Bromley                 20164
# Camden                  29183
# City of London            178
# Croydon                 28712
# Ealing                  27127
# Enfield                 22485
# Greenwich               22730
# Hackney                 28265
# Hammersmith and Fulham  20174
# Haringey                27174
# Harrow                  13153
# Havering                16903
# Hillingdon              24341
# Hounslow                22251
# Islington               27092
# Kensington and Chelsea  19580
# Kingston upon Thames     9983
# Lambeth                 34071
# Lewisham                23904
# Merton                  12755
# Newham                  30090
# Redbridge               19502
# Richmond upon Thames    11074
# Southwark               31636
# Sutton                  10658
# ...

# %%
count, bin_edges = np.histogram(frequency16)
print(count)
print(bin_edges)
# Out:
# [ 1  0  6  2 10  8  4  1  0  1]
# [  178.   4993.2  9808.4 14623.6 19438.8 24254.  29069.2 33884.4 38699.6
#  43514.8 48330. ]

# %%
frequency16.plot(kind="hist",
                     figsize=(10,7),
                     xticks=bin_edges,
                     yticks=count,
                     legend=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
top5_crime
# Out:
#               value
# borough
# Westminster  455028
# Lambeth      292178
# Southwark    278809
# Camden       275147
# Newham       262024

# %%
top3_crime = top5_crime.head(3)
top3_crime
# Out:
#               value
# borough
# Westminster  455028
# Lambeth      292178
# Southwark    278809

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
frequency_top3 = london_crime.drop(["lsoa_code","major_category","minor_category","month"],axis=1).set_index("borough")
frequency_top3 = frequency_top3.loc[top3_crime.index]
frequency_top3 = pd.pivot_table(frequency_top3, values="value", aggfunc=np.sum, index="year", columns="borough")
frequency_top3
# Out:
# borough  Lambeth  Southwark  Westminster
# year
# 2008       31717      33470        47846
# 2009       31225      30623        48456
# 2010       31671      31320        48116
# 2011       33224      30723        54243
# 2012       33473      30737        59226
# 2013       31868      31128        53852
# 2014       31765      28912        47564
# 2015       33164      30260        47395
# 2016       34071      31636        48330

# %%
count, bin_edges = np.histogram(frequency_top3)
print(count)
print(bin_edges)
# Out:
# [13  5  0  0  0  0  6  0  2  1]
# [28912.  31943.4 34974.8 38006.2 41037.6 44069.  47100.4 50131.8 53163.2
#  56194.6 59226. ]

# %%
frequency_top3.plot(kind="hist",
                     figsize=(10,7),
                     xticks=bin_edges,
                     yticks=count)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
top3_major = top5_major.head(3)

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
major3_freq = london_crime.drop(["lsoa_code","borough","minor_category","month"], axis=1).set_index("major_category")
major3_freq = major3_freq.loc[top3_major.index]
major3_freq = pd.pivot_table(major3_freq, values="value", aggfunc=np.sum, index="year", columns="major_category")
major3_freq
# Out:
# major_category  Burglary  Theft and Handling  Violence Against the Person
# year
# 2008               88092              283692                       159844
# 2009               90619              279492                       160777
# 2010               86826              290924                       157894
# 2011               93315              309292                       146901
# 2012               93392              334054                       150014
# 2013               87222              306372                       146181
# 2014               76053              279880                       185349
# 2015               70489              284022                       218740
# 2016               68285              294133                       232381

# %%
count, bin_edges = np.histogram(major3_freq)
print(count)
print(bin_edges)
# Out:
# [9 0 2 4 1 1 1 2 5 2]
# [ 68285.   94861.9 121438.8 148015.7 174592.6 201169.5 227746.4 254323.3
#  280900.2 307477.1 334054. ]

# %%
major3_freq.plot(kind="hist",
                     figsize=(10,7),
                     xticks=bin_edges,
                     yticks=count)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Bar Chart

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
totalCrimeEachType = london_crime.drop(["lsoa_code","borough","minor_category","year","month"], axis=1).groupby("major_category").sum()
totalCrimeEachType["value"].to_numpy()
totalCrimeEachType.plot(kind="bar",
                        figsize=(15,10),
                        legend=False,
                        color="maroon")
plt.title("Total Number of Crime from Each Type [2008-2016]\n", fontsize=20)
plt.xlabel("\nCrime Name", fontsize=15)
plt.ylabel("Number of Crime", fontsize=15)
plt.xticks(rotation=-45)
plt.yticks(fontsize=11)
plt.grid(color="grey", linewidth=0.2)
plt.show()

# %%
totalCrimeEachBorough = london_crime.drop(
    ["lsoa_code", "major_category", "minor_category", "year", "month"], axis=1).groupby("borough").sum()
totalCrimeEachBorough["value"].to_numpy()
totalCrimeEachBorough = totalCrimeEachBorough.sort_values(
    by="value", ascending=True)
totalCrimeEachBorough.plot(kind="barh",
                           figsize=(15, 10),
                           legend=False,
                           color="lightcoral")
plt.title("Total Number of Crime from Each Borough [2008-2016]", fontsize=20)
plt.xlabel("\nNumber of Crime", fontsize=15)
plt.ylabel("Borough Name\n", fontsize=15)
plt.yticks(fontsize=11)
plt.grid(color="grey", linewidth=0.2)
plt.show()

# %% [markdown]
# **MINOR CATEGORY**

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
minor_incidents = london_crime.drop(["lsoa_code","borough","year","month"],axis=1)
minor_incidents
# Out:
#                        major_category               minor_category  value
# 0                            Burglary  Burglary in Other Buildings      0
# 1         Violence Against the Person               Other violence      0
# 2         Violence Against the Person               Other violence      0
# 3                            Burglary  Burglary in Other Buildings      0
# 4                             Robbery            Personal Property      0
# ...                               ...                          ...    ...
# 13490599              Criminal Damage  Criminal Damage To Dwelling      0
# 13490600                      Robbery            Personal Property      1
# 13490601                     Burglary       Burglary in a Dwelling      0
# 13490602                      Robbery            Business Property      0
# 13490603  Violence Against the Person                 Wounding/GBH      0
#
# [13490604 rows x 3 columns]

# %%
minorIncidents = pd.pivot_table(minor_incidents, index=["major_category","minor_category"], values="value", aggfunc=np.sum)
minorIncidents
# Out:
#                                                                      value
# major_category              minor_category
# Burglary                    Burglary in Other Buildings             263011
#                             Burglary in a Dwelling                  491282
# Criminal Damage             Criminal Damage To Dwelling             154116
#                             Criminal Damage To Motor Vehicle        265463
#                             Criminal Damage To Other Building        66003
#                             Other Criminal Damage                   145356
# Drugs                       Drug Trafficking                         35819
#                             Other Drugs                               2998
#                             Possession Of Drugs                     431948
# Fraud or Forgery            Counted per Victim                        3840
#                             Other Fraud & Forgery                     1485
# ...

# %%
burglary_crime = minorIncidents.loc["Burglary"]
burglary_crime.plot(kind="barh",
                    figsize=(10,6),
                    legend=False,
                    color="orangered")
plt.title("Incidents by Minor Category (Burglary) [2008-2016]\n", fontsize=20)
plt.xlabel("\nNumber of Incidents", fontsize=15)
plt.ylabel("Minor Crime\n", fontsize=15)
plt.grid(color="grey", linewidth=0.2)
plt.show()

# %%
while True:
    insert_crime_name = input("")
    if not insert_crime_name in minorIncidents.index:
        print("ERROR! Please insert the right crime name (re-run this)")
        break;
    if insert_crime_name in minorIncidents.index:
        major_crime = minorIncidents.loc[insert_crime_name]
        major_crime.plot(kind="barh",
                            figsize=(10,6),
                            legend=False,
                            color="skyblue")
        plt.title("Incidents by Minor Category ({}) [2008-2016]\n".format(insert_crime_name), fontsize=20)
        plt.xlabel("\nNumber of Incidents", fontsize=15)
        plt.ylabel("Minor Crime\n", fontsize=15)
        plt.grid(color="grey", linewidth=0.2)
        plt.show()
print()
# Out:
# Violence Against the Person
# Drugs
# Done
# ERROR! Please insert the right crime name (re-run this)

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
top15Borough_theft = london_crime.drop(["lsoa_code","minor_category","year","month"], axis=1)
top15Borough_theft = pd.pivot_table(top15Borough_theft, index=["major_category","borough"], values="value", aggfunc=np.sum)
top15Borough_theft = top15Borough_theft.loc["Theft and Handling"].sort_values(by="value", ascending=True).tail(15)
top15Borough_theft.plot(kind="barh",
                        figsize=(10,6),
                        legend=False,
                        color="limegreen")
plt.title("Top 15 Borough with Highest Theft and Handling Number [2008-2016]\n", fontsize=20)
plt.xlabel("\nNumber of Crimes", fontsize=15)
plt.ylabel("Borough Name\n", fontsize=15)
plt.grid(color="grey", linewidth=0.2)
plt.show()

# %%
while True:
    insert_crime_name = input("")
    if not insert_crime_name in london_crime["major_category"].unique():
        print("ERROR! Please insert the right crime type (re-run this)")
        break;
    if insert_crime_name in london_crime["major_category"].unique():
        top15Borough_crime = london_crime.drop(["lsoa_code","minor_category","year","month"], axis=1)
        top15Borough_crime = pd.pivot_table(top15Borough_crime, index=["major_category","borough"], values="value", aggfunc=np.sum)
        top15Borough_crime = top15Borough_crime.loc[insert_crime_name].sort_values(by="value", ascending=True).tail(15)
        top15Borough_crime.plot(kind="barh",
                                figsize=(10,6),
                                legend=False,
                                color="slategrey")
        plt.title("Top 15 Borough with Highest {} Number [2008-2016]\n".format(insert_crime_name), fontsize=20)
        plt.xlabel("\nNumber of Crimes", fontsize=15)
        plt.ylabel("Borough Name\n", fontsize=15)
        plt.grid(color="grey", linewidth=0.2)
        plt.show()
print()
# Out:
# Criminal Damage
# Burglary
# Done
# ERROR! Please insert the right crime type (re-run this)

# %%
total_crime.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
crime2016 = london_crime.drop(["lsoa_code","major_category","minor_category","month"],axis=1).set_index("year")
crime2016 = crime2016.loc[2016]
crime2016 = crime2016.groupby("borough").sum().sort_values(by="value")
crime2016
# Out:
#                         value
# borough
# City of London            178
# Kingston upon Thames     9983
# Sutton                  10658
# Richmond upon Thames    11074
# Merton                  12755
# Bexley                  12840
# Harrow                  13153
# Barking and Dagenham    16741
# Havering                16903
# Redbridge               19502
# Kensington and Chelsea  19580
# Bromley                 20164
# Hammersmith and Fulham  20174
# Waltham Forest          20716
# Hounslow                22251
# Enfield                 22485
# Greenwich               22730
# Wandsworth              23679
# Lewisham                23904
# Hillingdon              24341
# Barnet                  24684
# Brent                   26693
# Islington               27092
# Ealing                  27127
# Haringey                27174
# Hackney                 28265
# Croydon                 28712
# Camden                  29183
# Tower Hamlets           29253
# ...

# %%
crime2016.plot(kind="barh", figsize=(20,10), legend=False)
# Out:
# <AxesSubplot:ylabel='borough'>

# %%
while True:
    insert_year = int(input(""))
    if not insert_year in london_crime["year"].unique():
        print("ERROR! Please insert the right year from 2008 to 2016")
        break;
    if insert_year in london_crime["year"].unique():
        year_crime = london_crime.drop(["lsoa_code","major_category","minor_category","month"],axis=1).set_index("year")
        year_crime = year_crime.loc[insert_year]
        year_crime = year_crime.groupby("borough").sum().sort_values(by="value")
        year_crime.plot(kind="barh", figsize=(20,10))
        plt.show()
print()
# Out:
# 2013
# 2008
# stop
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-36cc578a64b5> in <module>
#       1 while True:
# ----> 2     insert_year = int(input(""))
#       3     if not insert_year in london_crime["year"].unique():
#       4         print("ERROR! Please insert the right year from 2008 to 2016")
#       5         break;
#
# ValueError: invalid literal for int() with base 10: 'stop'

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
major2016 = london_crime.drop(["lsoa_code","borough","minor_category","month"], axis=1).set_index("year")
major2016 = major2016.loc[2016].groupby("major_category").sum()
major2016 = major2016.sort_values(by="value")
major2016
# Out:
#                               value
# major_category
# Fraud or Forgery                  0
# Sexual Offences                   0
# Other Notifiable Offences     15809
# Robbery                       22528
# Drugs                         38914
# Criminal Damage               64071
# Burglary                      68285
# Violence Against the Person  232381
# Theft and Handling           294133

# %%
major2016.plot(kind="barh", figsize=(10,7), color="brown", legend=False)
# Out:
# <AxesSubplot:ylabel='major_category'>

# %%
while True:
    insert_year = int(input(""))
    if not insert_year in london_crime["year"].unique():
        print("ERROR! Please insert the right year from 2008 to 2016")
        break;
    if insert_year in london_crime["year"].unique():
        yearMajor = london_crime.drop(["lsoa_code","borough","minor_category","month"],axis=1).set_index("year")
        yearMajor = yearMajor.loc[insert_year]
        yearMajor = yearMajor.groupby("major_category").sum().sort_values(by="value")
        yearMajor.plot(kind="barh", figsize=(10,7), legend=False, color="sandybrown")
        plt.show()
print()
# Out:
# 2010
# 0
# ERROR! Please insert the right year from 2008 to 2016

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
minor_crime = london_crime.drop(["lsoa_code","borough","major_category","month"], axis=1).set_index("year")
minor_crime = minor_crime.loc[2012].groupby("minor_category").sum().sort_values(by="value")
minor_crime
# Out:
#                                          value
# minor_category
# Rape                                         0
# Other Sexual                                 0
# Counted per Victim                           0
# Other Fraud & Forgery                        0
# Murder                                      95
# Other Drugs                                321
# Going Equipped                             600
# Handling Stolen Goods                     1737
# Business Property                         2450
# Offensive Weapon                          3134
# Drug Trafficking                          3964
# Motor Vehicle Interference & Tampering    5113
# Other violence                            6623
# Criminal Damage To Other Building         6753
# Wounding/GBH                              7151
# Other Notifiable                         10075
# Other Criminal Damage                    14298
# Criminal Damage To Dwelling              15330
# Theft/Taking of Pedal Cycle              21339
# ...

# %%
minor_crime.plot(kind="barh", figsize=(10,7), legend=False, color="crimson")
# Out:
# <AxesSubplot:ylabel='minor_category'>

# %% [markdown]
# ## Pie Chart

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
crime_proportion = london_crime.drop(["borough","lsoa_code","minor_category","year","month"], axis=1)
crime_proportion = crime_proportion.groupby("major_category").size()
crime_proportion
# Out:
# major_category
# Burglary                       1043604
# Criminal Damage                2069172
# Drugs                          1179468
# Fraud or Forgery                236520
# Other Notifiable Offences       776304
# Robbery                         939384
# Sexual Offences                 108108
# Theft and Handling             3966300
# Violence Against the Person    3171744
# dtype: int64

# %%
explode_list = [0,0,0,0.1,0.05,0.05,0.1,0,0]
color_list = ["lightcoral","navajowhite","lightcyan","violet","silver",
             "tan","cornflowerblue","brown","rosybrown"]
crime_proportion.plot(kind="pie",
                     figsize=(20,10),
                     autopct="%1.1f%%",
                     startangle=90,
                     shadow=True,
                     labels=None,
                     pctdistance=1.12,
                     explode = explode_list,
                     colors=color_list)
plt.title("Percentage of Crime in London from Each Category [2008-2016]\n", fontsize=20, loc="center")
plt.legend(labels=crime_proportion.index, loc="upper left", prop={"size":7.5})
plt.show()

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
redbridge_crime_proportion = london_crime.drop(["lsoa_code","minor_category","year","month"], axis=1).set_index("borough")
redbridge_crime_proportion = redbridge_crime_proportion.loc["Redbridge"]
redbridge_crime_proportion = redbridge_crime_proportion.groupby("major_category").sum()
redbridge_crime_proportion
# Out:
#                              value
# major_category
# Burglary                     26735
# Criminal Damage              17543
# Drugs                        15736
# Fraud or Forgery               284
# Other Notifiable Offences     2619
# Robbery                       7688
# Sexual Offences                 31
# Theft and Handling           71496
# Violence Against the Person  41430

# %%
explode_list = [0,0,0,0.15,0,0,0.15,0,0]
color_list = ["lightcoral","navajowhite","lightcyan","violet","silver",
             "tan","cornflowerblue","brown","rosybrown"]
redbridge_crime_proportion.plot(kind="pie",
                     figsize=(20,10),
                     autopct="%1.1f%%",
                     startangle=90,
                     shadow=True,
                     labels=None,
                     pctdistance=1.12,
                     colors=color_list,
                    explode = explode_list,
                               subplots=True)
plt.title("Percentage of Crime in Redbrigde, London [2008-2016]\n", fontsize=20, loc="center")
plt.legend(labels=redbridge_crime_proportion.index, loc="upper left", prop={"size":7.5})
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
while True:
    insert_borough = input("")
    if not insert_borough in london_crime["borough"].unique(): 
        print("ERROR! Please insert the right borough name")
        break;
    if insert_borough in london_crime["borough"].unique():
        borough_crime_proportion = london_crime.drop(["lsoa_code","minor_category","year","month"], axis=1).set_index("borough")
        borough_crime_proportion = borough_crime_proportion.loc[insert_borough]
        borough_crime_proportion = borough_crime_proportion.groupby("major_category").sum()
        explode_list = [0,0,0,0.15,0,0,0.15,0,0]
        borough_crime_proportion.plot(kind="pie",
                                         figsize=(20,10),
                                         autopct="%1.1f%%",
                                         startangle=90,
                                         shadow=False,
                                         labels=None,
                                         pctdistance=1.12,
                                         explode = explode_list,
                                         subplots=True)
        plt.title("Percentage of Crime in {} [2008-2016]\n".format(insert_borough), fontsize=20, loc="center")
        plt.legend(labels=borough_crime_proportion.index, loc="upper left", prop={"size":7.5})
        plt.show()
    print()
# Out:
# Greenwich
# No handles with labels found to put in legend.
# Sutton
# No handles with labels found to put in legend.
# Done
# ERROR! Please insert the right borough name

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
westYearCrime = london_crime.drop(["lsoa_code","minor_category","month"], axis=1).set_index("year")
westYearCrime = westYearCrime.loc[2010]
westYearCrime = pd.pivot_table(westYearCrime, values="value", aggfunc=np.sum, index="borough", columns="major_category")
westYearCrime = westYearCrime.loc["Westminster"].transpose()
westYearCrime
# Out:
# major_category
# Burglary                        2682.0
# Criminal Damage                 2385.0
# Drugs                           4632.0
# Fraud or Forgery                   0.0
# Other Notifiable Offences        660.0
# Robbery                         1439.0
# Sexual Offences                    0.0
# Theft and Handling             29191.0
# Violence Against the Person     7127.0
# Name: Westminster, dtype: float64

# %%
westYearCrime.plot(kind="pie", figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Westminster'>

# %% [markdown]
# ## Box Plot

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
total_crime
# Out:
#        value
# year
# 2008  738641
# 2009  717214
# 2010  715324
# 2011  724915
# 2012  737329
# 2013  686407
# 2014  680183
# 2015  711624
# 2016  736121

# %%
total_crime.describe()
# Out:
#                value
# count       9.000000
# mean   716417.555556
# std     21301.370555
# min    680183.000000
# 25%    711624.000000
# 50%    717214.000000
# 75%    736121.000000
# max    738641.000000

# %%
total_crime.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
crime_frequency
# Out:
#                          value
# borough
# Barking and Dagenham    149447
# Barnet                  212191
# Bexley                  114136
# Brent                   227551
# Bromley                 184349
# Camden                  275147
# City of London             780
# Croydon                 260294
# Ealing                  251562
# Enfield                 193880
# Greenwich               181568
# Hackney                 217119
# Hammersmith and Fulham  185259
# Haringey                213272
# Harrow                  116848
# Havering                138947
# Hillingdon              209680
# Hounslow                186772
# Islington               230286
# Kensington and Chelsea  171981
# Kingston upon Thames     89306
# Lambeth                 292178
# Lewisham                215137
# Merton                  115654
# Newham                  262024
# Redbridge               183562
# Richmond upon Thames     96771
# Southwark               278809
# Sutton                  100987
# ...

# %%
crime_frequency.describe()
# Out:
#                value
# count      33.000000
# mean   195386.606061
# std     79148.057551
# min       780.000000
# 25%    149447.000000
# 50%    203879.000000
# 75%    228613.000000
# max    455028.000000

# %%
crime_frequency.plot(kind="box", figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df_top5
# Out:
# borough  Camden  Lambeth  Newham  Southwark  Westminster
# year
# 2008      32010    31717   29752      33470        47846
# 2009      31612    31225   28610      30623        48456
# 2010      31804    31671   30728      31320        48116
# 2011      33956    33224   27978      30723        54243
# 2012      31472    33473   30067      30737        59226
# 2013      28435    31868   27577      31128        53852
# 2014      27198    31765   28005      28912        47564
# 2015      29477    33164   29217      30260        47395
# 2016      29183    34071   30090      31636        48330

# %%
df_top5.describe()
# Out:
# borough        Camden       Lambeth        Newham     Southwark   Westminster
# count        9.000000      9.000000      9.000000      9.000000      9.000000
# mean     30571.888889  32464.222222  29113.777778  30978.777778  50558.666667
# std       2121.547633   1014.515005   1119.162385   1215.293049   4201.683918
# min      27198.000000  31225.000000  27577.000000  28912.000000  47395.000000
# 25%      29183.000000  31717.000000  28005.000000  30623.000000  47846.000000
# 50%      31472.000000  31868.000000  29217.000000  30737.000000  48330.000000
# 75%      31804.000000  33224.000000  30067.000000  31320.000000  53852.000000
# max      33956.000000  34071.000000  30728.000000  33470.000000  59226.000000

# %%
df_top5.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
totalCrimeEachType
# Out:
#                                value
# major_category
# Burglary                      754293
# Criminal Damage               630938
# Drugs                         470765
# Fraud or Forgery                5325
# Other Notifiable Offences     106349
# Robbery                       258873
# Sexual Offences                 1273
# Theft and Handling           2661861
# Violence Against the Person  1558081

# %%
totalCrimeEachType.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
total_crime.plot(kind="box", ax=plt.figure().add_subplot(1,2,1))
total_crime.plot(kind="line", ax=plt.figure().add_subplot(1,2,2))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## Scatterplot

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
total_crime.reset_index(inplace=True)

# %%
total_crime.plot(kind="scatter", x="year", y="value")
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
COLscatter = london_crime.drop(["lsoa_code","major_category","minor_category","month"], axis=1).set_index("borough")
COLscatter = COLscatter.loc["City of London"].groupby("year").sum()
COLscatter = COLscatter.reset_index()

# %%
COLscatter.plot(kind="scatter", x="year",y="value", color="darkblue")
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
west_month = london_crime.drop(["lsoa_code","major_category","minor_category"], axis=1).set_index(["borough","year"])
west_month = west_month.loc["Westminster", 2016]
west_month = west_month.reset_index()
west_month.drop("year", axis=1, inplace=True)
west_month = west_month.groupby("month").sum()
west_month = west_month.reset_index()
west_month
# Out:
# <ipython-input-27-78873e048f77>:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   west_month = west_month.loc["Westminster", 2016]
#     month  value
# 0       1   4022
# 1       2   3755
# 2       3   3703
# 3       4   3736
# 4       5   3789
# 5       6   3785
# 6       7   4357
# 7       8   4291
# 8       9   3773
# 9      10   4093
# 10     11   4275
# 11     12   4751

# %%
months = np.arange(len(west_month["month"])+1)
name_of_months=['0','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
west_month.plot(kind="scatter", x="month",y="value",figsize=(15,10))
plt.xticks(months, name_of_months)
# Out:
# ([<matplotlib.axis.XTick at 0x1591426430>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, 'Jan'),
#   Text(2, 0, 'Feb'),
#   Text(3, 0, 'Mar'),
#   Text(4, 0, 'Apr'),
#   Text(5, 0, 'May'),
#   Text(6, 0, 'Jun'),
#   Text(7, 0, 'Jul'),
#   Text(8, 0, 'Aug'),
#   Text(9, 0, 'Sep'),
#   Text(10, 0, 'Oct'),
#   Text(11, 0, 'Nov'),
#   Text(12, 0, 'Dec')])

# %%
while True:
    insert_borough = input("")
    insert_year = int(input(""))
    if insert_borough in london_crime["borough"].unique() and insert_year in london_crime["year"].unique():
        west_month = london_crime.drop(["lsoa_code","major_category","minor_category"], axis=1).set_index(["borough","year"])
        west_month = west_month.loc[insert_borough, insert_year]
        west_month = west_month.reset_index()
        west_month.drop("year", axis=1, inplace=True)
        west_month = west_month.groupby("month").sum()
        west_month = west_month.reset_index()
        months = np.arange(len(west_month["month"])+1)
        name_of_months=['0','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
        west_month.plot(kind="scatter", x="month",y="value",figsize=(15,10), color="darkblue")
        plt.xticks(months, name_of_months)
        plt.show()
print()
# Out:
# Greenwich
# 2013
# <ipython-input-33-18cdc9527177>:6: PerformanceWarning: indexing past lexsort depth may impact performance.
#   west_month = west_month.loc[insert_borough, insert_year]
# Lambeth
# 2014
# stop
# stop
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-18cdc9527177> in <module>
#       1 while True:
#       2     insert_borough = input("")
# ----> 3     insert_year = int(input(""))
#       4     if insert_borough in london_crime["borough"].unique() and insert_year in london_crime["year"].unique():
#       5         west_month = london_crime.drop(["lsoa_code","major_category","minor_category"], axis=1).set_index(["borough","year"])
#
# ValueError: invalid literal for int() with base 10: 'stop'

# %%
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# - bikin yang masing-masing jenis major category nya per bulan di tahun ...
# - bikin overall number of crime fromm specific year each month
